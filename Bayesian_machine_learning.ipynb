# %% [markdown]
# #### Importing the Standard libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# #### loading the dataset

# %%
movehub_cost_of_living = pd.read_csv("data/movehubcostofliving.csv")
movehub_quality_of_living = pd.read_csv("data/movehubqualityoflife.csv")

# %% [markdown]
# #### Viewing the dataset

# %%
movehub_cost_of_living.head()
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 0  Lausanne        3.15   12.59   8.40      1.32   1714.00
# 1    Zurich        3.28   12.59   8.40      1.31   2378.61
# 2    Geneva        2.80   12.94  10.49      1.28   2607.95
# 3     Basel        3.50   11.89   7.35      1.25   1649.29
# 4     Perth        2.87   11.43  10.08      0.97   2083.14
#
#    Avg Disposable Income
# 0                4266.11
# 1                4197.55
# 2                3917.72
# 3                3847.76
# 4                3358.55

# %%
movehub_quality_of_living.head()
# Out:
#            City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0       Caracas           65.18           11.25        44.44      83.45
# 1  Johannesburg           84.08           53.99        59.98      47.39
# 2     Fortaleza           80.17           52.28        45.46      66.32
# 3   Saint Louis           85.25           80.40        77.29      31.33
# 4   Mexico City           75.07           24.28        61.76      18.95
#
#    Quality of Life  Crime Rating
# 0             8.61         85.70
# 1            51.26         83.93
# 2            36.68         78.65
# 3            87.51         78.13
# 4            27.91         77.86

# %% [markdown]
# #### Descriptive analysis of the dataset ( for getting the statistical view of dataset )

# %%
movehub_cost_of_living.describe()
# Out:
#        Cappuccino      Cinema        Wine    Gasoline     Avg Rent  \
# count  216.000000  216.000000  216.000000  216.000000   216.000000
# mean     1.981481    6.775602    7.079722    1.001898  1092.979213
# std      0.737131    5.632751    3.325691    0.351713   664.778486
# min      0.460000    1.810000    2.130000    0.070000   120.680000
# 25%      1.320000    4.397500    4.260000    0.735000   609.015000
# 50%      2.085000    6.540000    6.540000    0.950000   980.650000
# 75%      2.490000    7.850000    8.472500    1.320000  1388.095000
# max      4.480000   79.490000   26.150000    1.690000  5052.310000
#
#        Avg Disposable Income
# count             216.000000
# mean             1413.530463
# std               912.013027
# min               120.680000
# 25%               549.860000
# 50%              1535.415000
# 75%              2053.812500
# max              4266.110000

# %%
movehub_quality_of_living.describe()
# Out:
#        Movehub Rating  Purchase Power  Health Care   Pollution  \
# count      216.000000      216.000000   216.000000  216.000000
# mean        79.676713       46.477176    66.442824   45.240370
# std          6.501011       20.614519    14.416412   25.369741
# min         59.880000        6.380000    20.830000    0.000000
# 25%         75.070000       28.815000    59.420000   24.410000
# 50%         81.060000       49.220000    67.685000   37.210000
# 75%         84.020000       61.607500    77.207500   67.675000
# max        100.000000       91.850000    95.960000   92.420000
#
#        Quality of Life  Crime Rating
# count       216.000000    216.000000
# mean         59.994537     41.338611
# std          22.019376     16.416409
# min           5.290000      9.110000
# 25%          42.752500     29.375000
# 50%          65.150000     41.140000
# 75%          78.617500     51.327500
# max          97.910000     85.700000

# %% [markdown]
# ## Now I am setting up as per task requirement

# %% [markdown]
# ### 1 - Set-up (1) There is one outlier that you should change in the Movehubdata-sets: the price of a cinema ticket in Riyadh. You should change this value programmatically (i.e. using code) from 79.49 to 10.00.

# %%
movehub_cost_of_living[moviehub_cost_of_living['City'] == "Riyadh"]
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 114  Riyadh        1.69   79.49  17.43      0.08    610.14
#
#      Avg Disposable Income
# 114                 1394.6

# %% [markdown]
# ##### we need to change this price to 10.00

# %%
movehub_cost_of_living.loc[moviehub_cost_of_living['City'] == "Riyadh", "Cinema"] = 10

# %% [markdown]
# ###### Now checking whether is it changed or not

# %%
movehub_cost_of_living[moviehub_cost_of_living['City'] == "Riyadh"]
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 114  Riyadh        1.69    10.0  17.43      0.08    610.14
#
#      Avg Disposable Income
# 114                 1394.6

# %% [markdown]
# ### 2 - In your code, you should create a single dataframe representing the two data-sets movehubqualityoflife.csv and movehubcostofliving.csv.

# %%
data = pd.merge(movehub_cost_of_living, movehub_quality_of_living)
data.head()
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 0  Lausanne        3.15   12.59   8.40      1.32   1714.00
# 1    Zurich        3.28   12.59   8.40      1.31   2378.61
# 2    Geneva        2.80   12.94  10.49      1.28   2607.95
# 3     Basel        3.50   11.89   7.35      1.25   1649.29
# 4     Perth        2.87   11.43  10.08      0.97   2083.14
#
#    Avg Disposable Income  Movehub Rating  Purchase Power  Health Care  \
# 0                4266.11           87.21           90.77        65.85
# 1                4197.55           85.89           79.58        78.33
# 2                3917.72           83.27           61.22        74.88
# 3                3847.76           84.20           78.17        79.74
# 4                3358.55           95.38           62.11        80.56
#
#    Pollution  Quality of Life  Crime Rating
# 0      87.62            73.21         35.55
# 1      18.04            97.91         15.35
# 2      29.43            82.76         54.36
# ...

# %% [markdown]
# ### 3 - You should normalize all of the variables being used in the models

# %% [markdown]
# ##### we need to do normalization of all the vairables So that, our model will perform better. There are so many ways of normalization like Min-Max Scaling, Standard Scaling etc

# %% [markdown]
# ##### Sometimes we need all the value in between 0 to 1 that time we min-max scaler and In some cases we need all the variables in normal distributed like we need now.

# %% [markdown]
# ##### for bayesian linear regression we need all the variables in standard normally distributed. that's why I am using StandardScaling technic

# %%
from sklearn import preprocessing

# %%
data.head()
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 0  Lausanne        3.15   12.59   8.40      1.32   1714.00
# 1    Zurich        3.28   12.59   8.40      1.31   2378.61
# 2    Geneva        2.80   12.94  10.49      1.28   2607.95
# 3     Basel        3.50   11.89   7.35      1.25   1649.29
# 4     Perth        2.87   11.43  10.08      0.97   2083.14
#
#    Avg Disposable Income  Movehub Rating  Purchase Power  Health Care  \
# 0                4266.11           87.21           90.77        65.85
# 1                4197.55           85.89           79.58        78.33
# 2                3917.72           83.27           61.22        74.88
# 3                3847.76           84.20           78.17        79.74
# 4                3358.55           95.38           62.11        80.56
#
#    Pollution  Quality of Life  Crime Rating
# 0      87.62            73.21         35.55
# 1      18.04            97.91         15.35
# 2      29.43            82.76         54.36
# ...

# %%
data.iloc[:,1: ] = preprocessing.scale(data.iloc[:,1:])

# %%
data.head()
# Out:
#        City  Cappuccino    Cinema      Wine  Gasoline  Avg Rent  \
# 0  Lausanne    1.588907  2.311485  0.397916  0.906537  0.936347
# 1    Zurich    1.765676  2.311485  0.397916  0.878039  1.938416
# 2    Geneva    1.112990  2.443330  1.027816  0.792544  2.284204
# 3     Basel    2.064823  2.047793  0.081458  0.707049  0.838780
# 4     Perth    1.208174  1.874511  0.904247 -0.090904  1.492920
#
#    Avg Disposable Income  Movehub Rating  Purchase Power  Health Care  \
# 0               3.135049        1.161479        2.153614    -0.041217
# 1               3.059700        0.957962        1.609532     0.826474
# 2               2.752161        0.554011        0.716828     0.586607
# 3               2.675273        0.697398        1.540974     0.924506
# 4               2.137620        2.421126        0.760102     0.981518
#
#    Pollution  Quality of Life  Crime Rating
# 0   1.674360         0.601568     -0.353430
# 1  -1.074648         1.725913     -1.586765
# ...

# %% [markdown]
# #### Replacing the spaces between the column names, So that, I can use them in making the formulas

# %%
data.columns = ['City', 'Cappuccino', 'Cinema', 'Wine', 'Gasoline', 'Avg_Rent', 'Avg_Disposable_Income', 'Movehub_Rating', 'Purchase_Power', 'Health_Care', 'Pollution', 'Quality_of_Life', 'Crime_Rating']

# %% [markdown]
# #### Using pymc3, you need to  create three Bayesian linear regression models

# %%
import pymc3 as pm

# %% [markdown]
# #### To implement Bayesian Linear Regression Model first we have to make the formula for all the three models

# %% [markdown]
# ##### model 1 - Purchase Power and Average Disposable Income

# %%
formula1 = 'Movehub_Rating ~ Purchase_Power + Avg_Disposable_Income'
formula1
# Out:
# 'Movehub_Rating ~ Purchase_Power + Avg_Disposable_Income'

# %% [markdown]
# #### model 2 -  all five variables in movehubqualityoflife.csv only

# %%
formula2 = 'Movehub_Rating ~ Purchase_Power + Health_Care + Pollution + Quality_of_Life + Crime_Rating'
formula2
# Out:
# 'Movehub_Rating ~ Purchase_Power + Health_Care + Pollution + Quality_of_Life + Crime_Rating'

# %% [markdown]
# #### model 3 - all eleven independent variables

# %%
formula3 = 'Movehub_Rating ~ Cappuccino + Cinema + Wine + Gasoline + Avg_Rent + Avg_Disposable_Income + Purchase_Power + Health_Care + Pollution + Quality_of_Life + Crime_Rating'
formula3
# Out:
# 'Movehub_Rating ~ Cappuccino + Cinema + Wine + Gasoline + Avg_Rent + Avg_Disposable_Income + Purchase_Power + Health_Care + Pollution + Quality_of_Life + Crime_Rating'

# %% [markdown]
# #### Model 1 creating and  analysis of the model parameters

# %%
with pm.Model() as normal_model:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula1, data = data, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    trace_1 = pm.sample(draws=2000, chains = 2, tune = 500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [sd, Avg_Disposable_Income, Purchase_Power, Intercept]
# Sampling 2 chains: 100%|██████████| 5000/5000 [06:21<00:00,  7.73draws/s]

# %% [markdown]
# ### Examine Bayesian Linear Regression Results

# %% [markdown]
# ### Traceplot of All Samples

# %%
pm.traceplot(trace_1)
plt.show()

# %% [markdown]
# ##### The left side of the traceplot is the marginal posterior: the values for the variable are on the x-axis with the probability for the variable (as determined by sampling) on the y-axis. The different colored lines indicate that we performed two chains of Markov Chain Monte Carlo. From the left side we can see that there is a range of values for each weight. The right side shows the different sample values drawn as the sampling process runs.

# %% [markdown]
# lets see the distribution of each sampled parameter. This plot allows us to see the uncertainty in each sample. The forestplot is easily constructed from the trace using pm.forestplot.

# %%
pm.forestplot(trace_1)
plt.show()

# %% [markdown]
# ##### From the forest plot we can see the most likely value of the parameter (the dot) as well as the 95% credible interval for the parameter. we can clearly see that purchase power and avg_disposable income both parameters are very uncertain So, we can say that, it is not good to use this model because this model has so much uncertainity.

# %% [markdown]
# ##### we can also see the distribution of different parameters via this method

# %%
pm.plot_posterior(trace_1)
plt.show()

# %%
pm.summary(trace_1)
# Out:
#                            mean        sd  mc_error   hpd_2.5  hpd_97.5  \
# Intercept              0.000334  0.036911  0.000592 -0.072627  0.071692
# Purchase_Power         0.611729  0.068164  0.001169  0.475944  0.742848
# Avg_Disposable_Income  0.260686  0.068052  0.001243  0.130025  0.391684
# sd                     0.547742  0.026975  0.000476  0.496162  0.601949
#
#                              n_eff      Rhat
# Intercept              4151.052231  0.999978
# Purchase_Power         2699.739776  0.999762
# Avg_Disposable_Income  2751.905105  0.999780
# sd                     3591.468906  1.000002

# %% [markdown]
# #### It is good to take mean value of each parameter for the prediction equation.

# %% [markdown]
# ##### Now, I repeated the same thing with other models as well

# %% [markdown]
# #### Model 2 creating and  analysis of the model parameters

# %%
with pm.Model() as normal_model:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula2, data = data, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    trace_2 = pm.sample(draws=2000, chains = 2, tune = 500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [sd, Crime_Rating, Quality_of_Life, Pollution, Health_Care, Purchase_Power, Intercept]
# Sampling 2 chains: 100%|██████████| 5000/5000 [09:46<00:00,  4.69draws/s]

# %%
pm.traceplot(trace_2)
plt.show()

# %%
pm.forestplot(trace_2)
plt.show()

# %%
pm.plot_posterior(trace_2)
plt.show()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002E2AE18ECC0>,
# ...
#       dtype=object)

# %%
pm.summary(trace_2)
# Out:
#                      mean        sd  mc_error   hpd_2.5  hpd_97.5  \
# Intercept       -0.000352  0.037272  0.000619 -0.074672  0.070813
# Purchase_Power   0.751532  0.076945  0.001589  0.590436  0.891672
# Health_Care      0.094743  0.043628  0.000823  0.001696  0.173309
# Pollution       -0.084481  0.040298  0.000722 -0.160710 -0.003763
# Quality_of_Life  0.036328  0.090847  0.002113 -0.141977  0.216220
# Crime_Rating     0.007801  0.044373  0.000839 -0.079827  0.092178
# sd               0.552701  0.026502  0.000397  0.504195  0.605779
#
#                        n_eff      Rhat
# Intercept        3954.156928  0.999753
# Purchase_Power   2306.510783  1.000519
# Health_Care      2750.283488  1.000052
# Pollution        3383.588590  0.999772
# Quality_of_Life  1957.420341  1.001666
# Crime_Rating     3033.001293  1.000260
# sd               4451.274226  0.999750

# %% [markdown]
# #### Model 3 creating and  analysis of the model parameters

# %%
with pm.Model() as normal_model:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula3, data = data, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    trace_3 = pm.sample(draws=2000, chains = 2, tune = 500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [sd, Crime_Rating, Quality_of_Life, Pollution, Health_Care, Purchase_Power, Avg_Disposable_Income, Avg_Rent, Gasoline, Wine, Cinema, Cappuccino, Intercept]
# Sampling 2 chains: 100%|██████████| 5000/5000 [17:01<00:00,  2.47draws/s]
# The acceptance probability does not match the target. It is 0.8814223889663035, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace_3)
plt.show()

# %%
pm.forestplot(trace_3)
plt.show()

# %%
pm.plot_posterior(trace_3)
plt.show()

# %%
pm.summary(trace_3)
# Out:
#                            mean        sd  mc_error   hpd_2.5  hpd_97.5  \
# Intercept              0.000298  0.032867  0.000453 -0.060707  0.069313
# Cappuccino            -0.131147  0.058540  0.000873 -0.249779 -0.017900
# Cinema                 0.133203  0.069982  0.001369 -0.008877  0.265982
# Wine                   0.076925  0.047350  0.000908 -0.019606  0.166762
# Gasoline               0.138943  0.047597  0.000914  0.051658  0.239679
# Avg_Rent               0.330594  0.056193  0.000927  0.217720  0.435020
# Avg_Disposable_Income -0.301673  0.118791  0.002801 -0.546622 -0.080185
# Purchase_Power         0.820666  0.085873  0.001723  0.650086  0.982871
# Health_Care            0.036709  0.039562  0.000595 -0.035640  0.119308
# Pollution              0.008865  0.039212  0.000570 -0.074270  0.079845
# Quality_of_Life        0.138773  0.085877  0.001469 -0.032936  0.302647
# Crime_Rating           0.060017  0.041995  0.000659 -0.018541  0.144747
# ...

# %% [markdown]
# #### These are some extra function which you can use for analysis of model like finding priors.

# %% [markdown]
# ##### to print the value of parameters in the given model

# %%
def print_parameter_values(trace):
    # Print out the mean variable weight from the trace
    for variable in trace.varnames:
        print('Variable: {:15} Mean weight in model: {:.4f}'.format(variable, 
                                                                    np.mean(trace[variable])))

# %% [markdown]
# #### this function is useful to get an idea like which parameter is good for model, how is it affeting the result and all.

# %% [markdown]
# #### If we want to see the effect of changing one variable while holding the others constant, we can use the function pm.plot_posterior_predictive_glm. This takes a range of values to use for the variable, a linear model, and a number of samples. The function evaluates the linear model across the range of values for the number of samples. Each time, it draws a different set of parameters from the trace. This gives us an indication of the effect of a single variable and also the uncertainty in the model estimates. To see the effect of a single variable, we hold the others constant at their median values

# %%
# Examines the effect of changing a single variable
# Takes in the name of the variable, the trace, and the data
def model_effect(query_var, trace, X):
    
    # Variables that do not change
    steady_vars = list(X.columns)
    steady_vars.remove(query_var)
    
    # Linear Model that estimates a Movehub_Rating based on the value of the query variable 
    # and one sample from the trace
    def lm(value, sample):
        # Prediction is the estimate given a value of the query variable
        prediction = sample['Intercept'] + sample[query_var] * value
        
        # Each non-query variable is assumed to be at the median value
        for var in steady_vars:
            
            # Multiply the weight by the median value of the variable
            prediction += sample[var] * X[var].median()
        
        return prediction
    
    plt.figure(figsize = (6, 6))
    
    # Find the minimum and maximum values for the range of the query var
    var_min = X[query_var].min()
    var_max = X[query_var].max()
    
    # Plot the estimated grade versus the range of query variable
    pm.plot_posterior_predictive_glm(trace, eval=np.linspace(var_min, var_max, 100), 
                                     lm=lm, samples=100, color='blue', 
                                     alpha = 0.4, lw = 2)
    
    # Plot formatting
    plt.xlabel('%s' % query_var, size = 16)
    plt.ylabel('Movehub_Rating', size = 16)
    plt.title("Posterior of Movehub_Rating vs %s" % query_var, size = 18)
    plt.show()

# %%
print_parameter_values(trace_1)
# Out:
# Variable: Intercept       Mean weight in model: 0.0003
# Variable: Purchase_Power  Mean weight in model: 0.6117
# Variable: Avg_Disposable_Income Mean weight in model: 0.2607
# Variable: sd_log__        Mean weight in model: -0.6032
# Variable: sd              Mean weight in model: 0.5477

# %% [markdown]
# #this can be the values of priori. with this we can estimate that
# #purchase power is directly propotional to move_hub rating. which means if we have more purchase power then we have high movehubRating.
# #avg disposal also have positive empact but less than the purchase power.

# %%
print_parameter_values(trace_2)
# Out:
# Variable: Intercept       Mean weight in model: -0.0004
# Variable: Purchase_Power  Mean weight in model: 0.7515
# Variable: Health_Care     Mean weight in model: 0.0947
# Variable: Pollution       Mean weight in model: -0.0845
# Variable: Quality_of_Life Mean weight in model: 0.0363
# Variable: Crime_Rating    Mean weight in model: 0.0078
# Variable: sd_log__        Mean weight in model: -0.5941
# Variable: sd              Mean weight in model: 0.5527

# %%
print_parameter_values(trace_3)
# Out:
# Variable: Intercept       Mean weight in model: 0.0003
# Variable: Cappuccino      Mean weight in model: -0.1311
# Variable: Cinema          Mean weight in model: 0.1332
# Variable: Wine            Mean weight in model: 0.0769
# Variable: Gasoline        Mean weight in model: 0.1389
# Variable: Avg_Rent        Mean weight in model: 0.3306
# Variable: Avg_Disposable_Income Mean weight in model: -0.3017
# Variable: Purchase_Power  Mean weight in model: 0.8207
# Variable: Health_Care     Mean weight in model: 0.0367
# Variable: Pollution       Mean weight in model: 0.0089
# Variable: Quality_of_Life Mean weight in model: 0.1388
# Variable: Crime_Rating    Mean weight in model: 0.0600
# Variable: sd_log__        Mean weight in model: -0.7099
# Variable: sd              Mean weight in model: 0.4923

# %% [markdown]
# ##### Here We can see the avg disposable has negative impact on the movehub rating but in the 1st model it was positive. it is happenning because, fir5st model got only 2 variable and it doesn't have the entire picture but in 3rd one it has all the variables

# %%
model_effect("Cinema", trace_3, data.iloc[:,1:].drop(columns = "Movehub_Rating"))

# %% [markdown]
# ##### if these lines vary too much then the variable is not good for the model and it is creating the noise, In Cinema variable case, it is ok to have it but lets check for the wine

# %%
model_effect("Wine", trace_3, data.iloc[:,1:].drop(columns = "Movehub_Rating"))

# %% [markdown]
# #### Checking the MCMC convergence for each model

# %% [markdown]
# ##### for checking convergence, there is no fixed way but we can check convergence of the model via multiple ways, I am sharing a link by which u can learn this thing in details

# %%
pm.autocorrplot(trace_1)
plt.show()

# %%
pm.autocorrplot(trace_2)
plt.show()

# %%
pm.autocorrplot(trace_3)
plt.show()

# %% [markdown]
# #### As we can the variables are almost normally distributed and In autocorrelation graph every thing looks good. there is no bias like parameters are not changing only in one direction.

# %% [markdown]
# #### So, I think these models are having convergence

# %%
# You can also gelman_rubin method to verify
# pm.gelman_rubin(trace_1)
# pm.gelman_rubin(trace_2)
# pm.gelman_rubin(trace_3)
